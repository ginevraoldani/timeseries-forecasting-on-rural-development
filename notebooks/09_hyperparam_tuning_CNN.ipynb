# %% [markdown]
# # <a id='toc1_'></a>[Hyperparameter Tuning of 1D conv net](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Hyperparameter Tuning of 1D conv net](#toc1_)
#   - [Import](#toc1_1_)
#   - [Setup](#toc1_2_)
#   - [Upload](#toc1_3_)
#   - [Splitting + augmentation + saving](#toc1_4_)
#   - [Scaling + saving](#toc1_5_)
#   - [Creation lag features table with n_input_step fixed](#toc1_6_)
#     - [Iperparametri Architetturali (Specifici CNN)](#toc1_6_1_)
#     - [Iperparametri Strutturali (Simili all'MLP)](#toc1_6_2_)
#     - [Iperparametri di Training (Identici all'MLP)](#toc1_6_3_)
#   - [Definition of search space = objective function for RandomSearch and Optuna](#toc1_7_)
#   - [Future preds - REFITTING ON FULL TIME SERIES](#toc1_8_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## <a id='toc1_1_'></a>[Import](#toc0_)

# %%
from src.config import set_seeds, RANDOM_SEED
import src.pipeline as pipe
import src.models as mod
import src.models.nn as nn
import src.evaluation as eval
import src.visualization as visual
import src.reporting as rep
import pandas as pd
import tensorflow as tf
import numpy as np
import time
import gc
import optuna
import pickle
from tensorflow.keras.callbacks import ModelCheckpoint # type: ignore
from optuna_integration.tfkeras import TFKerasPruningCallback
from optuna.samplers import RandomSampler, TPESampler
from sklearn.preprocessing import MinMaxScaler

# %%
set_seeds()
# Out:
# Random seeds set to 42. Deterministic operations enabled.

# %% [markdown]
# ## <a id='toc1_2_'></a>[Setup](#toc0_)

# %%
INDICATORS = ['fertilizer_percent']

DF_CATEGORIES = ['orig', 'step_aug', 'jitter_aug']

# %% [markdown]
# ## <a id='toc1_3_'></a>[Upload](#toc0_)

# %%
df = pipe.load_data()
display(df.head())
# Out:
# Dropped 9 unusable indicators.
# Dataset loaded: 65 years (from 1960 to 2024), 27 variables.
#             population_percent  population_growth  population_abs  \
# 1960-01-01              40.639                NaN      20400656.0
# 1961-01-01              40.144          -0.557139      20287312.0
# 1962-01-01              39.645          -0.574190      20171158.0
# 1963-01-01              39.147          -0.534554      20063620.0
# 1964-01-01              38.650          -0.455075      19972523.0
#
#             employment_tot  employment_male  employment_female  \
# 1960-01-01             NaN              NaN                NaN
# 1961-01-01             NaN              NaN                NaN
# 1962-01-01             NaN              NaN                NaN
# 1963-01-01             NaN              NaN                NaN
# 1964-01-01             NaN              NaN                NaN
#
#             forestarea_percent  forestarea_abs  agriland_percent  \
# 1960-01-01                 NaN             NaN               NaN
# 1961-01-01                 NaN             NaN         70.324028
# 1962-01-01                 NaN             NaN         70.218626
# 1963-01-01                 NaN             NaN         69.735813
# 1964-01-01                 NaN             NaN         69.572609
#
#             agriland_abs  ...  fertilizer_percent  livestock_production_index  \
# 1960-01-01           NaN  ...                 NaN                         NaN
# 1961-01-01      206830.0  ...           72.707716                       70.91
# 1962-01-01      206520.0  ...           70.071359                       72.59
# 1963-01-01      205100.0  ...           63.883735                       65.95
# 1964-01-01      204620.0  ...           64.593354                       69.57
#
#             food_production_index  crop_production_index  cereal_production  \
# 1960-01-01                    NaN                    NaN                NaN
# 1961-01-01                  85.93                  93.68         13933400.0
# 1962-01-01                  86.90                  94.43         14433210.0
# 1963-01-01                  86.37                  97.19         13324660.0
# 1964-01-01                  90.28                 101.31         14007520.0
#
#             cerealyield_abs  valueadded_percent  valueadded_dollars  \
# 1960-01-01              NaN                 NaN                 NaN
# 1961-01-01           2181.5                 NaN                 NaN
# 1962-01-01           2225.3                 NaN                 NaN
# 1963-01-01           2115.2                 NaN                 NaN
# 1964-01-01           2243.0                 NaN                 NaN
#
#             exports_percent  imports_percent
# 1960-01-01              NaN              NaN
# 1961-01-01              NaN              NaN
# 1962-01-01         2.563660        16.566057
# 1963-01-01         2.651714        14.571604
# 1964-01-01         2.792923        15.115329
#
# [5 rows x 27 columns]

# %% [markdown]
# ## <a id='toc1_4_'></a>[Splitting + augmentation + saving](#toc0_)

# %%
orig_aug_subsets = {}

for col in df.columns:
    print('='*30, col.upper(), '='*30)
    subset = df[[col]].copy()
    subset['Year'] = subset.index.year
    subset.rename(columns={col: 'Value'}, inplace=True)
    subset = subset[['Year', 'Value']]
    subset = subset.dropna()
    train_orig, val_orig, test_orig = pipe.split_train_val_test(subset)    # splitto la time serie ORIGINALE
    
    x_train_vals = train_orig['Year']
    y_train_vals = train_orig['Value']
    
    df_step = pipe.augment_step_function(x_train_vals, y_train_vals, scale_factor=10)
    df_jitter = pipe.augment_linear_with_jitter(x_train_vals, y_train_vals, scale_factor=10, noise_level=0.05)
    visual.plot_augmented(col, df_step, df_jitter, x_train_vals, y_train_vals)
    orig_aug_subsets[col] = {
        'full_orig': subset,
        'orig_train': train_orig,
        'step_aug_train': df_step,
        'jitter_aug_train': df_jitter,
        'orig_val': val_orig,
        'orig_test': test_orig
    }
# Out:
# ============================== POPULATION_PERCENT ==============================
# Train: 1960-2004 (45 obs)
# Val:   2005-2014 (10 obs)
# Test:  2015-2024 (10 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_population_percent.png
# ============================== POPULATION_GROWTH ==============================
# Train: 1961-2004 (44 obs)
# Val:   2005-2015 (11 obs)
# Test:  2016-2024 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_population_growth.png
# ============================== POPULATION_ABS ==============================
# Train: 1960-2004 (45 obs)
# Val:   2005-2014 (10 obs)
# Test:  2015-2024 (10 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_population_abs.png
# ============================== EMPLOYMENT_TOT ==============================
# Train: 1991-2013 (23 obs)
# Val:   2014-2018 (5 obs)
# Test:  2019-2023 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_employment_tot.png
# ============================== EMPLOYMENT_MALE ==============================
# Train: 1991-2013 (23 obs)
# Val:   2014-2018 (5 obs)
# Test:  2019-2023 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_employment_male.png
# ============================== EMPLOYMENT_FEMALE ==============================
# Train: 1991-2013 (23 obs)
# Val:   2014-2018 (5 obs)
# Test:  2019-2023 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_employment_female.png
# ============================== FORESTAREA_PERCENT ==============================
# Train: 1990-2012 (23 obs)
# Val:   2013-2017 (5 obs)
# Test:  2018-2022 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_forestarea_percent.png
# ============================== FORESTAREA_ABS ==============================
# Train: 1990-2012 (23 obs)
# Val:   2013-2017 (5 obs)
# Test:  2018-2022 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_forestarea_abs.png
# ============================== AGRILAND_PERCENT ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_agriland_percent.png
# ============================== AGRILAND_ABS ==============================
# Train: 1961-2002 (42 obs)
# Val:   2003-2012 (10 obs)
# Test:  2013-2021 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_agriland_abs.png
# ============================== ARABLELAND_PERCENT ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_arableland_percent.png
# ============================== ARABLELAND_PERSON ==============================
# Train: 1961-2002 (42 obs)
# Val:   2003-2012 (10 obs)
# Test:  2013-2021 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_arableland_person.png
# ============================== ARABLELAND_ABS ==============================
# Train: 1961-2002 (42 obs)
# Val:   2003-2012 (10 obs)
# Test:  2013-2021 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_arableland_abs.png
# ============================== CEREALLAND_ABS ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_cerealland_abs.png
# ============================== CROPLAND_PERCENT ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_cropland_percent.png
# ============================== WITHDRAWALS_PERCENT ==============================
# Train: 1970-2005 (36 obs)
# Val:   2006-2013 (8 obs)
# Test:  2014-2021 (8 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_withdrawals_percent.png
# ============================== FERTILIZER_ABS ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_fertilizer_abs.png
# ============================== FERTILIZER_PERCENT ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_fertilizer_percent.png
# ============================== LIVESTOCK_PRODUCTION_INDEX ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_livestock_production_index.png
# ============================== FOOD_PRODUCTION_INDEX ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_food_production_index.png
# ============================== CROP_PRODUCTION_INDEX ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_crop_production_index.png
# ============================== CEREAL_PRODUCTION ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_cereal_production.png
# ============================== CEREALYIELD_ABS ==============================
# Train: 1961-2003 (43 obs)
# Val:   2004-2013 (10 obs)
# Test:  2014-2022 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_cerealyield_abs.png
# ============================== VALUEADDED_PERCENT ==============================
# Train: 1990-2013 (24 obs)
# Val:   2014-2019 (6 obs)
# Test:  2020-2024 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_valueadded_percent.png
# ============================== VALUEADDED_DOLLARS ==============================
# Train: 1990-2013 (24 obs)
# Val:   2014-2019 (6 obs)
# Test:  2020-2024 (5 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_valueadded_dollars.png
# ============================== EXPORTS_PERCENT ==============================
# Train: 1962-2005 (44 obs)
# Val:   2006-2015 (10 obs)
# Test:  2016-2024 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_exports_percent.png
# ============================== IMPORTS_PERCENT ==============================
# Train: 1962-2005 (44 obs)
# Val:   2006-2015 (10 obs)
# Test:  2016-2024 (9 obs)
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\AUGMENTATION\AUG_imports_percent.png

# %% [markdown]
# ## <a id='toc1_5_'></a>[Scaling + saving](#toc0_)

# %%
scaled_orig_aug_subsets = {} 
scalers_subsets = {}
for indicator in INDICATORS:
    scaled_subsets, scalers = pipe.scale_datasets(orig_aug_subsets[indicator])
    scaled_orig_aug_subsets[indicator] = scaled_subsets
    scalers_subsets[indicator] = scalers

# %% [markdown]
# ## <a id='toc1_6_'></a>[Creation lag features table with window size fixed](#toc0_)

# %%
scaled_table_subsets = {}
for indicator in INDICATORS:
    window_size = 3
    table_train_orig = pipe.create_lag_features_table(scaled_orig_aug_subsets[indicator]['orig_train'], window_size, step=1)
    table_train_step = pipe.create_lag_features_table(scaled_orig_aug_subsets[indicator]['step_aug_train'], window_size, step=1)
    table_train_jitter = pipe.create_lag_features_table(scaled_orig_aug_subsets[indicator]['jitter_aug_train'], window_size, step=1)
    table_val_orig = pipe.create_lag_features_table(scaled_orig_aug_subsets[indicator]['orig_val'], window_size, step=1)
    table_test_orig = pipe.create_lag_features_table(scaled_orig_aug_subsets[indicator]['orig_test'], window_size, step=1)
    scaled_table_subsets[indicator] = {
        'train_orig' : table_train_orig,
        'train_step' : table_train_step,
        'train_jitter' : table_train_jitter,
        'val_orig' : table_val_orig,
        'test_orig' : table_test_orig
    }

# %%
final_table_train_sets = {}
final_table_val_test_sets = {}

for indicator in INDICATORS:
    # X: filtra colonne ts_*
    # y: prende colonna 'target'
    X_train_orig_to_reshape = scaled_table_subsets[indicator]['train_orig'].filter(regex=r'^ts_').copy()
    y_train_orig_to_reshape = scaled_table_subsets[indicator]['train_orig']['target'].copy()
    
    X_train_step_to_reshape = scaled_table_subsets[indicator]['train_step'].filter(regex=r'^ts_').copy()
    y_train_step_to_reshape = scaled_table_subsets[indicator]['train_step']['target'].copy()
    
    X_train_jitter_to_reshape = scaled_table_subsets[indicator]['train_jitter'].filter(regex=r'^ts_').copy()
    y_train_jitter_to_reshape = scaled_table_subsets[indicator]['train_jitter']['target'].copy()
    
    X_val_orig_to_reshape = scaled_table_subsets[indicator]['val_orig'].filter(regex=r'^ts_').copy()
    y_val_orig_to_reshape = scaled_table_subsets[indicator]['val_orig']['target'].copy()
    
    X_test_orig_to_reshape = scaled_table_subsets[indicator]['test_orig'].filter(regex=r'^ts_').copy()
    y_test_orig_to_reshape = scaled_table_subsets[indicator]['test_orig']['target'].copy()
    
    # Reshape X: (samples, window_size, 1)
    X_train_orig = X_train_orig_to_reshape.values.reshape((X_train_orig_to_reshape.shape[0], X_train_orig_to_reshape.shape[1], 1))
    X_train_step = X_train_step_to_reshape.values.reshape((X_train_step_to_reshape.shape[0], X_train_step_to_reshape.shape[1], 1))
    X_train_jitter = X_train_jitter_to_reshape.values.reshape((X_train_jitter_to_reshape.shape[0], X_train_jitter_to_reshape.shape[1], 1))
    X_val_orig = X_val_orig_to_reshape.values.reshape((X_val_orig_to_reshape.shape[0], X_val_orig_to_reshape.shape[1], 1))
    X_test_orig = X_test_orig_to_reshape.values.reshape((X_test_orig_to_reshape.shape[0], X_test_orig_to_reshape.shape[1], 1))
    
    # Reshape y: (samples, 1)
    y_train_orig = y_train_orig_to_reshape.values.reshape(-1, 1)
    y_train_step = y_train_step_to_reshape.values.reshape(-1, 1)
    y_train_jitter = y_train_jitter_to_reshape.values.reshape(-1, 1)
    y_val_orig = y_val_orig_to_reshape.values.reshape(-1, 1)
    y_test_orig = y_test_orig_to_reshape.values.reshape(-1, 1)
    
    final_table_train_sets[indicator] = {
        'train_orig' : (X_train_orig, y_train_orig),
        'train_step' : (X_train_step, y_train_step),
        'train_jitter' : (X_train_jitter, y_train_jitter),
    }
    
    final_table_val_test_sets[indicator] = {
        'val_orig': (X_val_orig, y_val_orig),
        'test_orig' : (X_test_orig, y_test_orig)
    }
    
    # print("train orig", X_train_orig[0], y_train_orig[0])
    # print("step", X_train_step[0], y_train_step[0])
    # print("jitter", X_train_jitter[0], y_train_jitter[0])
    # print("val", X_val_orig[0], y_val_orig[0])
    # print("test", X_test_orig[0], y_test_orig[0])

# %% [markdown]
# ### <a id='toc1_6_1_'></a>[Iperparametri Architetturali (Specifici CNN)](#toc0_)
# - **Number of Filters**: [16, 32, 64, 128]. Più filtri = più capacità di vedere dettagli, ma più rischio overfitting.
# - **Kernel Size**: [3, 5, 7].
#     - Piccolo (3): Vede dettagli fini/rumore ad alta frequenza.
#     - Grande (7): Vede trend più ampi/lisciati.
# - **Pooling Type**: [MaxPooling, AveragePooling, None]. A volte con soli 60 punti, non fare pooling è meglio (o usare "Global Average Pooling" alla fine).
# - **Number of Conv Blocks**: [1, 2].
# <br>
# Attenzione: Se metti 3 layer di pooling (diviso 2 tre volte), 60 diventa 7.5 -> 7 punti. Con 4 layer arrivi a 3 punti. Optuna deve sapere di non esagerare con la profondità su serie corte.
#
# ### <a id='toc1_6_2_'></a>[Iperparametri Strutturali (Simili all'MLP)](#toc0_)
# - **Dense Layer Size**: quanti neuroni nel layer dopo il Flatten.
# - **Dropout Rate**: [0.2 - 0.5] dopo la convoluzione o dopo il dense layer.
#
# ### <a id='toc1_6_3_'></a>[Iperparametri di Training (Identici all'MLP)](#toc0_)
# - **Learning Rate**.
# - **Batch Size**.
# - **Optimizer** (Adam, RMSprop, ecc.).

# %% [markdown]
# Per una CNN, spesso servono finestre più ampie rispetto a un MLP per catturare pattern

# %% [markdown]
# ## <a id='toc1_7_'></a>[Definition of search space = objective function for RandomSearch and Optuna](#toc0_)

# %%
def objective(trial, scaled_data_dict):
    n_input_steps = trial.suggest_int('n_input_steps', 3, 6) 
    
    # Search Space
    params = {
        # Struttura Convoluzionale
        'n_conv_layers': trial.suggest_int('n_conv_layers', 1, 2),      # Numero di blocchi Conv
        'filters': trial.suggest_categorical('filters', [16, 32, 64]),
        'kernel_size': trial.suggest_int('kernel_size', 2, 4),          # Quanto è grande la "lente" della conv
        'pool_size': 2,                                                 # volendo posso tunarlo (es. suggest_int(2,3))
        
        # Struttura Dense (Head della rete)
        'dense_units': trial.suggest_int('dense_units', 16, 64),
        'activation': 'relu', # Relu è standard per CNN, ma posso usare trial.suggest nel caso
        
        # Training
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True),
        'batch_size': trial.suggest_categorical('batch_size', [16, 32]),
        'dropout': trial.suggest_float('dropout', 0.1, 0.4),
        'input_shape': (n_input_steps, 1)
    }
    
    # Check di sicurezza: il kernel non può essere più grande dell'input
    if params['kernel_size'] >= n_input_steps:
        raise optuna.TrialPruned()
    
    train_data = scaled_data_dict['train']
    val_data = scaled_data_dict['val']
    
    X_train, y_train = pipe.create_sequences(train_data['Value'], n_input_steps)
    X_val, y_val = pipe.create_sequences(val_data['Value'], n_input_steps)
    
    if len(X_train) == 0 or len(X_val) == 0:
        raise optuna.TrialPruned()
    
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

    model = nn.build_cnn_model(params) 
    
    pruning_callback = TFKerasPruningCallback(trial, "val_loss")
    
    history, model = nn.train_model(    
        model, 
        X_train, y_train, 
        X_val, y_val,
        batch_size=params['batch_size'],
        epochs=50, 
        patience=10,
        extra_callbacks=[pruning_callback]
    )
    
    if 'val_loss' not in history.history:
        return float('inf')
        
    best_val_loss = min(history.history['val_loss'])
    return best_val_loss

# %%
tuning_results = []
BACKUP_FILE = "tuning_results_cnn_backup.pkl"
N_TRIALS = 20

pruner = optuna.pruners.HyperbandPruner(min_resource=5, max_resource=50, reduction_factor=3)

for SAMPLER_MODE in ["Random", "TPE"]:
    for indicator in INDICATORS:
        print(f"\n{'='*40} PROCESSING: {indicator} [{SAMPLER_MODE}] {'='*40}")
        
        for df_category in DF_CATEGORIES:
            print(f"\n Optimizing: {df_category}")
            
            if SAMPLER_MODE == "Random":
                sampler = RandomSampler(seed=42)
            else:
                sampler = TPESampler(seed=42, n_startup_trials=10) 
        
            try:
                data_package = {
                    'train': scaled_orig_aug_subsets[indicator][f'{df_category}_train'],
                    'val': scaled_orig_aug_subsets[indicator]['orig_val']
                }
            except KeyError as e:
                print(f"Data Error: dataset {e} missing for {indicator}. Skipping.")
                continue
            
            study_name = f"CNN_{indicator}_{df_category}_{SAMPLER_MODE}"
            study = optuna.create_study(
                direction='minimize', 
                sampler=sampler, 
                pruner=pruner,
                study_name=study_name
            )
            
            try:
                study.optimize(
                    lambda trial: objective(trial, data_package), 
                    n_trials=N_TRIALS,
                    gc_after_trial=True # Pulisce la memoria dopo ogni trial
                )
            except Exception as e:
                print(f"Optuna crash on {indicator} - {df_category}: {e}")
                continue

            result_entry = {
                "indicator": indicator,
                "sampler": SAMPLER_MODE,
                "dataset_type": df_category,
                "best_params": study.best_params,
                "best_val_loss": study.best_value,
                "n_trials": N_TRIALS,
                "model_type": "CNN"
            }
            
            tuning_results.append(result_entry)
            print(f"Saved params for {indicator} ({df_category}) -> Loss: {study.best_value:.5f}")

            with open(BACKUP_FILE, "wb") as f:
                pickle.dump(tuning_results, f)
            
            tf.keras.backend.clear_session()
            gc.collect()

print(f"\nOptimal params found for {len(tuning_results)} configurations.")
# Out:
# [I 2026-01-30 15:27:10,799] A new study created in memory with name: CNN_fertilizer_percent_orig_Random
# ======================================== PROCESSING: fertilizer_percent [Random] ========================================
#
#  Optimizing: orig
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [I 2026-01-30 15:27:17,555] Trial 0 finished with value: 0.11353156715631485 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 18, 'learning_rate': 0.005399484409787433, 'batch_size': 32, 'dropout': 0.10617534828874074}. Best is trial 0 with value: 0.11353156715631485.
# [I 2026-01-30 15:27:26,349] Trial 1 finished with value: 0.026976928114891052 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 41, 'learning_rate': 0.0007309539835912913, 'batch_size': 32, 'dropout': 0.14184815819561256}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:27:41,137] Trial 2 finished with value: 0.08489660173654556 and parameters: {'n_input_steps': 4, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 3, 'dense_units': 45, 'learning_rate': 0.0001238513729886094, 'batch_size': 16, 'dropout': 0.11951547789558387}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:27:45,302] Trial 3 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:27:51,461] Trial 4 finished with value: 0.31344687938690186 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 2, 'dense_units': 63, 'learning_rate': 0.0035503048581283078, 'batch_size': 16, 'dropout': 0.2793699936433256}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:27:56,972] Trial 5 finished with value: 0.054454486817121506 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 29, 'learning_rate': 0.004544383960336014, 'batch_size': 16, 'dropout': 0.2628088249474746}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:28:01,307] Trial 6 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:28:14,128] Trial 7 finished with value: 1.105838656425476 and parameters: {'n_input_steps': 3, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 2, 'dense_units': 19, 'learning_rate': 0.0004187594718900631, 'batch_size': 32, 'dropout': 0.29126724140656396}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:28:18,243] Trial 8 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:28:18,611] Trial 9 pruned.
# [I 2026-01-30 15:28:18,916] Trial 10 pruned.
# [I 2026-01-30 15:28:30,602] Trial 11 finished with value: 0.058281309902668 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 58, 'learning_rate': 0.00010325337616482048, 'batch_size': 16, 'dropout': 0.1666323431412191}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:28:30,916] Trial 12 pruned.
# [I 2026-01-30 15:28:35,961] Trial 13 finished with value: 0.18680638074874878 and parameters: {'n_input_steps': 4, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 2, 'dense_units': 29, 'learning_rate': 0.0065543823435462835, 'batch_size': 16, 'dropout': 0.24683582808326893}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:28:41,036] Trial 14 finished with value: 0.07072049379348755 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 4, 'dense_units': 34, 'learning_rate': 0.0018391267498289018, 'batch_size': 16, 'dropout': 0.1270869310163225}. Best is trial 1 with value: 0.026976928114891052.
# [I 2026-01-30 15:28:47,404] Trial 15 finished with value: 0.021461201831698418 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 16, 'learning_rate': 0.0010572705046816896, 'batch_size': 32, 'dropout': 0.15230992870149745}. Best is trial 15 with value: 0.021461201831698418.
# [I 2026-01-30 15:28:52,225] Trial 16 finished with value: 0.023720908910036087 and parameters: {'n_input_steps': 5, 'n_conv_layers': 1, 'filters': 16, 'kernel_size': 2, 'dense_units': 61, 'learning_rate': 0.005684322462212271, 'batch_size': 32, 'dropout': 0.3451666600603648}. Best is trial 15 with value: 0.021461201831698418.
# [I 2026-01-30 15:28:59,922] Trial 17 finished with value: 0.041305869817733765 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 4, 'dense_units': 47, 'learning_rate': 0.0004764963542138519, 'batch_size': 32, 'dropout': 0.3691330779857732}. Best is trial 15 with value: 0.021461201831698418.
# [I 2026-01-30 15:29:03,849] Trial 18 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:29:04,202] Trial 19 pruned.
# Saved params for fertilizer_percent (orig) -> Loss: 0.02146
# WARNING:tensorflow:From c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# [I 2026-01-30 15:29:05,323] A new study created in memory with name: CNN_fertilizer_percent_step_aug_Random
#  Optimizing: step_aug
# [I 2026-01-30 15:29:12,185] Trial 0 finished with value: 0.2876647412776947 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 18, 'learning_rate': 0.005399484409787433, 'batch_size': 32, 'dropout': 0.10617534828874074}. Best is trial 0 with value: 0.2876647412776947.
# [I 2026-01-30 15:29:19,242] Trial 1 finished with value: 0.028573088347911835 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 41, 'learning_rate': 0.0007309539835912913, 'batch_size': 32, 'dropout': 0.14184815819561256}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:29:27,541] Trial 2 finished with value: 0.04771633446216583 and parameters: {'n_input_steps': 4, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 3, 'dense_units': 45, 'learning_rate': 0.0001238513729886094, 'batch_size': 16, 'dropout': 0.11951547789558387}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:29:32,655] Trial 3 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:29:39,031] Trial 4 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:29:43,881] Trial 5 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:29:48,209] Trial 6 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:29:56,809] Trial 7 finished with value: 0.9818234443664551 and parameters: {'n_input_steps': 3, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 2, 'dense_units': 19, 'learning_rate': 0.0004187594718900631, 'batch_size': 32, 'dropout': 0.29126724140656396}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:30:01,841] Trial 8 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:30:02,323] Trial 9 pruned.
# [I 2026-01-30 15:30:02,785] Trial 10 pruned.
# [I 2026-01-30 15:30:09,773] Trial 11 finished with value: 0.049676306545734406 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 58, 'learning_rate': 0.00010325337616482048, 'batch_size': 16, 'dropout': 0.1666323431412191}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:30:10,189] Trial 12 pruned.
# [I 2026-01-30 15:30:15,158] Trial 13 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:30:22,597] Trial 14 finished with value: 0.2217773050069809 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 4, 'dense_units': 34, 'learning_rate': 0.0018391267498289018, 'batch_size': 16, 'dropout': 0.1270869310163225}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:30:28,492] Trial 15 finished with value: 0.10216310620307922 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 16, 'learning_rate': 0.0010572705046816896, 'batch_size': 32, 'dropout': 0.15230992870149745}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:30:34,227] Trial 16 finished with value: 0.45808926224708557 and parameters: {'n_input_steps': 5, 'n_conv_layers': 1, 'filters': 16, 'kernel_size': 2, 'dense_units': 61, 'learning_rate': 0.005684322462212271, 'batch_size': 32, 'dropout': 0.3451666600603648}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:30:38,814] Trial 17 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:30:45,153] Trial 18 finished with value: 0.04276304692029953 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 45, 'learning_rate': 0.0001043263716130209, 'batch_size': 32, 'dropout': 0.10151847515386561}. Best is trial 1 with value: 0.028573088347911835.
# [I 2026-01-30 15:30:45,591] Trial 19 pruned.
# Saved params for fertilizer_percent (step_aug) -> Loss: 0.02857
# [I 2026-01-30 15:30:47,079] A new study created in memory with name: CNN_fertilizer_percent_jitter_aug_Random
#  Optimizing: jitter_aug
# [I 2026-01-30 15:30:53,438] Trial 0 finished with value: 0.2755930721759796 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 18, 'learning_rate': 0.005399484409787433, 'batch_size': 32, 'dropout': 0.10617534828874074}. Best is trial 0 with value: 0.2755930721759796.
# [I 2026-01-30 15:31:00,473] Trial 1 finished with value: 0.07769635319709778 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 41, 'learning_rate': 0.0007309539835912913, 'batch_size': 32, 'dropout': 0.14184815819561256}. Best is trial 1 with value: 0.07769635319709778.
# [I 2026-01-30 15:31:09,560] Trial 2 finished with value: 0.16031305491924286 and parameters: {'n_input_steps': 4, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 3, 'dense_units': 45, 'learning_rate': 0.0001238513729886094, 'batch_size': 16, 'dropout': 0.11951547789558387}. Best is trial 1 with value: 0.07769635319709778.
# [I 2026-01-30 15:31:16,618] Trial 3 finished with value: 0.06370282173156738 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 37, 'learning_rate': 0.00017541893487450815, 'batch_size': 16, 'dropout': 0.37279612062363465}. Best is trial 3 with value: 0.06370282173156738.
# [I 2026-01-30 15:31:22,293] Trial 4 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:31:32,159] Trial 5 finished with value: 0.1370522379875183 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 29, 'learning_rate': 0.004544383960336014, 'batch_size': 16, 'dropout': 0.2628088249474746}. Best is trial 3 with value: 0.06370282173156738.
# [I 2026-01-30 15:31:38,152] Trial 6 finished with value: 1.1416105031967163 and parameters: {'n_input_steps': 3, 'n_conv_layers': 2, 'filters': 32, 'kernel_size': 2, 'dense_units': 16, 'learning_rate': 0.004274869455295219, 'batch_size': 32, 'dropout': 0.3313811040057838}. Best is trial 3 with value: 0.06370282173156738.
# [I 2026-01-30 15:31:42,763] Trial 7 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:31:47,687] Trial 8 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:31:48,187] Trial 9 pruned.
# [I 2026-01-30 15:31:48,668] Trial 10 pruned.
# [I 2026-01-30 15:31:55,488] Trial 11 finished with value: 0.03254718333482742 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 58, 'learning_rate': 0.00010325337616482048, 'batch_size': 16, 'dropout': 0.1666323431412191}. Best is trial 11 with value: 0.03254718333482742.
# [I 2026-01-30 15:31:56,024] Trial 12 pruned.
# [I 2026-01-30 15:32:01,000] Trial 13 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:32:13,388] Trial 14 finished with value: 0.1644057184457779 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 4, 'dense_units': 34, 'learning_rate': 0.0018391267498289018, 'batch_size': 16, 'dropout': 0.1270869310163225}. Best is trial 11 with value: 0.03254718333482742.
# [I 2026-01-30 15:32:19,153] Trial 15 finished with value: 0.06888177990913391 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 16, 'learning_rate': 0.0010572705046816896, 'batch_size': 32, 'dropout': 0.15230992870149745}. Best is trial 11 with value: 0.03254718333482742.
# [I 2026-01-30 15:32:23,809] Trial 16 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:32:29,948] Trial 17 finished with value: 0.00952387135475874 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 4, 'dense_units': 47, 'learning_rate': 0.0004764963542138519, 'batch_size': 32, 'dropout': 0.3691330779857732}. Best is trial 17 with value: 0.00952387135475874.
# [I 2026-01-30 15:32:37,085] Trial 18 finished with value: 0.025123953819274902 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 45, 'learning_rate': 0.0001043263716130209, 'batch_size': 32, 'dropout': 0.10151847515386561}. Best is trial 17 with value: 0.00952387135475874.
# [I 2026-01-30 15:32:37,633] Trial 19 pruned.
# Saved params for fertilizer_percent (jitter_aug) -> Loss: 0.00952
# [I 2026-01-30 15:32:39,439] A new study created in memory with name: CNN_fertilizer_percent_orig_TPE
# ======================================== PROCESSING: fertilizer_percent [TPE] ========================================
#
#  Optimizing: orig
# [I 2026-01-30 15:32:45,973] Trial 0 finished with value: 0.10918587446212769 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 18, 'learning_rate': 0.005399484409787433, 'batch_size': 32, 'dropout': 0.10617534828874074}. Best is trial 0 with value: 0.10918587446212769.
# [I 2026-01-30 15:32:53,532] Trial 1 finished with value: 0.02680991217494011 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 41, 'learning_rate': 0.0007309539835912913, 'batch_size': 32, 'dropout': 0.14184815819561256}. Best is trial 1 with value: 0.02680991217494011.
# [I 2026-01-30 15:32:57,629] Trial 2 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:33:10,519] Trial 3 finished with value: 0.03311759606003761 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 37, 'learning_rate': 0.00017541893487450815, 'batch_size': 16, 'dropout': 0.37279612062363465}. Best is trial 1 with value: 0.02680991217494011.
# [I 2026-01-30 15:33:16,735] Trial 4 finished with value: 0.2725585997104645 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 2, 'dense_units': 63, 'learning_rate': 0.0035503048581283078, 'batch_size': 16, 'dropout': 0.2793699936433256}. Best is trial 1 with value: 0.02680991217494011.
# [I 2026-01-30 15:33:21,054] Trial 5 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:33:25,200] Trial 6 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:33:30,083] Trial 7 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:33:36,446] Trial 8 finished with value: 0.027058694511651993 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 53, 'learning_rate': 0.0009718319944817398, 'batch_size': 16, 'dropout': 0.10762573802322856}. Best is trial 1 with value: 0.02680991217494011.
# [I 2026-01-30 15:33:37,166] Trial 9 pruned.
# [I 2026-01-30 15:33:44,799] Trial 10 finished with value: 0.07003414630889893 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 47, 'learning_rate': 0.0016382533314418545, 'batch_size': 32, 'dropout': 0.19760799939138549}. Best is trial 1 with value: 0.02680991217494011.
# [I 2026-01-30 15:33:49,026] Trial 11 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:33:55,888] Trial 12 finished with value: 0.021695241332054138 and parameters: {'n_input_steps': 5, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 53, 'learning_rate': 0.00034814757963989954, 'batch_size': 32, 'dropout': 0.1823454919847443}. Best is trial 12 with value: 0.021695241332054138.
# [I 2026-01-30 15:34:03,464] Trial 13 finished with value: 0.026019686833024025 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 4, 'dense_units': 38, 'learning_rate': 0.00026858415429856626, 'batch_size': 32, 'dropout': 0.18399729258109146}. Best is trial 12 with value: 0.021695241332054138.
# [I 2026-01-30 15:34:12,113] Trial 14 finished with value: 0.013726195320487022 and parameters: {'n_input_steps': 5, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 35, 'learning_rate': 0.0002674701807186936, 'batch_size': 32, 'dropout': 0.2052755011891428}. Best is trial 14 with value: 0.013726195320487022.
# [I 2026-01-30 15:34:17,431] Trial 15 finished with value: 0.014140335842967033 and parameters: {'n_input_steps': 5, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 31, 'learning_rate': 0.0003723575044358803, 'batch_size': 32, 'dropout': 0.22499154533705737}. Best is trial 14 with value: 0.013726195320487022.
# [I 2026-01-30 15:34:23,521] Trial 16 pruned. Trial was pruned at epoch 15.
# [I 2026-01-30 15:34:35,028] Trial 17 pruned. Trial was pruned at epoch 45.
# [I 2026-01-30 15:34:36,129] Trial 18 pruned.
# [I 2026-01-30 15:34:42,254] Trial 19 finished with value: 0.04981524869799614 and parameters: {'n_input_steps': 5, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 4, 'dense_units': 24, 'learning_rate': 0.0020515762784143743, 'batch_size': 32, 'dropout': 0.22454973602025924}. Best is trial 14 with value: 0.013726195320487022.
# Saved params for fertilizer_percent (orig) -> Loss: 0.01373
# [I 2026-01-30 15:34:44,249] A new study created in memory with name: CNN_fertilizer_percent_step_aug_TPE
#  Optimizing: step_aug
# [I 2026-01-30 15:34:50,263] Trial 0 finished with value: 0.40227052569389343 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 18, 'learning_rate': 0.005399484409787433, 'batch_size': 32, 'dropout': 0.10617534828874074}. Best is trial 0 with value: 0.40227052569389343.
# [I 2026-01-30 15:34:57,587] Trial 1 finished with value: 0.04490330070257187 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 41, 'learning_rate': 0.0007309539835912913, 'batch_size': 32, 'dropout': 0.14184815819561256}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:35:06,567] Trial 2 finished with value: 0.11223243921995163 and parameters: {'n_input_steps': 4, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 3, 'dense_units': 45, 'learning_rate': 0.0001238513729886094, 'batch_size': 16, 'dropout': 0.11951547789558387}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:35:14,067] Trial 3 finished with value: 0.12068173289299011 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 37, 'learning_rate': 0.00017541893487450815, 'batch_size': 16, 'dropout': 0.37279612062363465}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:35:21,074] Trial 4 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:35:26,173] Trial 5 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:35:32,615] Trial 6 finished with value: 1.1100854873657227 and parameters: {'n_input_steps': 3, 'n_conv_layers': 2, 'filters': 32, 'kernel_size': 2, 'dense_units': 16, 'learning_rate': 0.004274869455295219, 'batch_size': 32, 'dropout': 0.3313811040057838}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:35:40,840] Trial 7 finished with value: 0.9953833222389221 and parameters: {'n_input_steps': 3, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 2, 'dense_units': 19, 'learning_rate': 0.0004187594718900631, 'batch_size': 32, 'dropout': 0.29126724140656396}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:35:47,529] Trial 8 finished with value: 0.23668867349624634 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 53, 'learning_rate': 0.0009718319944817398, 'batch_size': 16, 'dropout': 0.10762573802322856}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:35:48,219] Trial 9 pruned.
# [I 2026-01-30 15:35:55,011] Trial 10 finished with value: 0.05522443726658821 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 47, 'learning_rate': 0.0016382533314418545, 'batch_size': 32, 'dropout': 0.19760799939138549}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:36:02,353] Trial 11 finished with value: 0.06058470532298088 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 47, 'learning_rate': 0.0018438132952276539, 'batch_size': 32, 'dropout': 0.18892736704542573}. Best is trial 1 with value: 0.04490330070257187.
# [I 2026-01-30 15:36:08,176] Trial 12 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:36:15,144] Trial 13 finished with value: 0.040064431726932526 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 3, 'dense_units': 38, 'learning_rate': 0.00042760373154238047, 'batch_size': 32, 'dropout': 0.1921913211991853}. Best is trial 13 with value: 0.040064431726932526.
# [I 2026-01-30 15:36:23,913] Trial 14 finished with value: 0.04231712222099304 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 3, 'dense_units': 35, 'learning_rate': 0.0002895343193833998, 'batch_size': 32, 'dropout': 0.16312882844160237}. Best is trial 13 with value: 0.040064431726932526.
# [I 2026-01-30 15:36:30,432] Trial 15 finished with value: 0.10081206262111664 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 3, 'dense_units': 32, 'learning_rate': 0.00027753043860988605, 'batch_size': 32, 'dropout': 0.16730782708552713}. Best is trial 13 with value: 0.040064431726932526.
# [I 2026-01-30 15:36:39,246] Trial 16 finished with value: 0.012343567796051502 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 24, 'learning_rate': 0.00033154340027512956, 'batch_size': 32, 'dropout': 0.22510442047695986}. Best is trial 16 with value: 0.012343567796051502.
# [I 2026-01-30 15:36:46,010] Trial 17 finished with value: 0.034472350031137466 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 24, 'learning_rate': 0.0004820589937370416, 'batch_size': 32, 'dropout': 0.2299132030249867}. Best is trial 16 with value: 0.012343567796051502.
# [I 2026-01-30 15:36:52,283] Trial 18 finished with value: 0.05976037681102753 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 4, 'dense_units': 24, 'learning_rate': 0.00021286833927395592, 'batch_size': 32, 'dropout': 0.23766836018117055}. Best is trial 16 with value: 0.012343567796051502.
# [I 2026-01-30 15:36:59,707] Trial 19 finished with value: 0.06440518796443939 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 32, 'kernel_size': 4, 'dense_units': 24, 'learning_rate': 0.0004991234041800165, 'batch_size': 32, 'dropout': 0.2286973707375308}. Best is trial 16 with value: 0.012343567796051502.
# Saved params for fertilizer_percent (step_aug) -> Loss: 0.01234
# [I 2026-01-30 15:37:02,157] A new study created in memory with name: CNN_fertilizer_percent_jitter_aug_TPE
#  Optimizing: jitter_aug
# [I 2026-01-30 15:37:08,307] Trial 0 finished with value: 0.5402786731719971 and parameters: {'n_input_steps': 4, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 18, 'learning_rate': 0.005399484409787433, 'batch_size': 32, 'dropout': 0.10617534828874074}. Best is trial 0 with value: 0.5402786731719971.
# [I 2026-01-30 15:37:15,428] Trial 1 finished with value: 0.024120040237903595 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 2, 'dense_units': 41, 'learning_rate': 0.0007309539835912913, 'batch_size': 32, 'dropout': 0.14184815819561256}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:37:23,479] Trial 2 finished with value: 0.0699901282787323 and parameters: {'n_input_steps': 4, 'n_conv_layers': 1, 'filters': 32, 'kernel_size': 3, 'dense_units': 45, 'learning_rate': 0.0001238513729886094, 'batch_size': 16, 'dropout': 0.11951547789558387}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:37:32,704] Trial 3 finished with value: 0.060054294764995575 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 37, 'learning_rate': 0.00017541893487450815, 'batch_size': 16, 'dropout': 0.37279612062363465}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:37:39,105] Trial 4 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:37:50,890] Trial 5 finished with value: 0.15789395570755005 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 29, 'learning_rate': 0.004544383960336014, 'batch_size': 16, 'dropout': 0.2628088249474746}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:37:56,807] Trial 6 finished with value: 0.943418025970459 and parameters: {'n_input_steps': 3, 'n_conv_layers': 2, 'filters': 32, 'kernel_size': 2, 'dense_units': 16, 'learning_rate': 0.004274869455295219, 'batch_size': 32, 'dropout': 0.3313811040057838}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:01,563] Trial 7 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:38:09,983] Trial 8 finished with value: 0.16386502981185913 and parameters: {'n_input_steps': 6, 'n_conv_layers': 1, 'filters': 64, 'kernel_size': 3, 'dense_units': 53, 'learning_rate': 0.0009718319944817398, 'batch_size': 16, 'dropout': 0.10762573802322856}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:10,939] Trial 9 pruned.
# [I 2026-01-30 15:38:16,657] Trial 10 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:38:22,949] Trial 11 finished with value: 0.05040830001235008 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 37, 'learning_rate': 0.0001858311497609689, 'batch_size': 32, 'dropout': 0.3832527051746889}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:29,208] Trial 12 finished with value: 0.03136160597205162 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 36, 'learning_rate': 0.00030312089529844035, 'batch_size': 32, 'dropout': 0.20253993383876703}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:35,959] Trial 13 finished with value: 0.06686775386333466 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 4, 'dense_units': 29, 'learning_rate': 0.0003757399348641474, 'batch_size': 32, 'dropout': 0.1921913211991853}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:42,094] Trial 14 finished with value: 0.2567386329174042 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 3, 'dense_units': 42, 'learning_rate': 0.00174531464753504, 'batch_size': 32, 'dropout': 0.18340714679347006}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:48,994] Trial 15 finished with value: 0.08186506479978561 and parameters: {'n_input_steps': 5, 'n_conv_layers': 2, 'filters': 16, 'kernel_size': 3, 'dense_units': 53, 'learning_rate': 0.00040905563041324897, 'batch_size': 32, 'dropout': 0.15996492808800408}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:38:56,137] Trial 16 pruned. Trial was pruned at epoch 15.
# [I 2026-01-30 15:39:00,848] Trial 17 pruned. Trial was pruned at epoch 5.
# [I 2026-01-30 15:39:07,752] Trial 18 finished with value: 0.31906962394714355 and parameters: {'n_input_steps': 6, 'n_conv_layers': 2, 'filters': 64, 'kernel_size': 3, 'dense_units': 60, 'learning_rate': 0.001798206872845896, 'batch_size': 32, 'dropout': 0.22721198928099856}. Best is trial 1 with value: 0.024120040237903595.
# [I 2026-01-30 15:39:13,367] Trial 19 pruned. Trial was pruned at epoch 5.
# Saved params for fertilizer_percent (jitter_aug) -> Loss: 0.02412
#
# Optimal params found for 6 configurations.

# %%
predictions_dict = {}
print(f"Refitting on {len(tuning_results)} CNN configurations.")

tf.keras.utils.set_random_seed(RANDOM_SEED)
tf.config.experimental.enable_op_determinism()

for entry in tuning_results:
    ind = entry['indicator']
    sampler = entry['sampler']
    ds_type = entry['dataset_type']
    
    params = entry['best_params'].copy()
    
    print(f"\nRefitting: {ind} | {sampler} | {ds_type} ...")
    
    scaler_y = scalers_subsets[ind]['scaler_y']
    train_df = scaled_orig_aug_subsets[ind][f'{ds_type}_train']
    val_df = scaled_orig_aug_subsets[ind]['orig_val']
    test_df = scaled_orig_aug_subsets[ind]['orig_test']
    
    n_steps = params['n_input_steps']
    
    X_train, y_train = pipe.create_sequences(train_df['Value'], n_steps)
    X_val, y_val = pipe.create_sequences(val_df['Value'], n_steps)
    X_test, y_test = pipe.create_sequences(test_df['Value'], n_steps)
    
    if len(X_test) == 0:
        print(f"SKIP {ind} - {ds_type}: test set is too short for window {n_steps}")
        continue

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    
    params['input_shape'] = (n_steps, 1)
    
    start_time = time.time()
    model = nn.build_cnn_model(params)
    
    history, model = nn.train_model(
        model, X_train, y_train, X_val, y_val, 
        batch_size=params['batch_size'], 
        epochs=150, 
        patience=20
    )
    elapsed_time = time.time() - start_time
    
    y_pred_scaled = model.predict(X_test, verbose=0)
    
    y_pred_real = scaler_y.inverse_transform(y_pred_scaled).flatten()
    y_test_real = scaler_y.inverse_transform(y_test).flatten()
    
    aligned_years = test_df['Year'].values[n_steps:]
    
    if len(aligned_years) != len(y_test_real):
        print(f"ERROR year dimension: expected {len(y_test_real)}, found {len(aligned_years)}")
        continue

    if ind not in predictions_dict: predictions_dict[ind] = {}
    if sampler not in predictions_dict[ind]: predictions_dict[ind][sampler] = {}

    metrics = eval.compute_errors(y_test_real, y_pred_real)
    predictions_dict[ind][sampler][ds_type] = {
        'years': aligned_years,
        'y_true': y_test_real,
        'y_pred': y_pred_real,
        'params': params,
        'metrics': metrics
    }
    
    try:
        pred_residuals = eval.compute_residual_diagnostics(y_test_real, y_pred_real)
        print(f"  -> Residuals: Mean={pred_residuals.get('residual_mean', 0):.4f}, "
            f"Shapiro P={pred_residuals.get('shapiro_wilk_pvalue', 0):.4f}, "
            f"Ljung-Box P={pred_residuals.get('ljung_box_pvalue', 0):.4f}")
    except Exception as e:
        print(f"  -> Residual diagnostics failed: {e}")
        pred_residuals = {}
    
    try:
        visual.plot_residuals(
            y_true=y_test_real,
            y_pred=y_pred_real,
            variable_name=col,
            model_name="CNN",
            folder_name="09_residCNN"
        )
    except Exception as e:
        print(f"Residual plot failed: {e}")
    
    rep.save_experiment_results(
        indicator=ind,
        model_name="CNN",
        configuration=f"{sampler}_{ds_type}",
        y_test=y_test_real,
        y_pred=y_pred_real,
        years_test=aligned_years,
        y_train=None,
        params=params,
        training_time=elapsed_time,
    )
    print("DONE")
    
    tf.keras.backend.clear_session()
    del model
    gc.collect()

print("\nCompleted CNN refitting.")
# Out:
# Refitting on 6 CNN configurations.
#
# Refitting: fertilizer_percent | Random | orig ...
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   -> Residuals: Mean=-49.2201, Shapiro P=0.1492, Ljung-Box P=0.7346
# Cartella creata: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN
# Diagnostics saved: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN\RESIDCNN_imports_percent.png
# Saving results for CNN | fertilizer_percent...
# Leaderboard updated: fertilizer_percent | CNN
# Save leaderboard complete.
# DONE
#
# Refitting: fertilizer_percent | Random | step_aug ...
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   -> Residuals: Mean=-66.4533, Shapiro P=0.1827, Ljung-Box P=0.5385
# Diagnostics saved: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN\RESIDCNN_imports_percent.png
# Saving results for CNN | fertilizer_percent...
# Leaderboard updated: fertilizer_percent | CNN
# Save leaderboard complete.
# DONE
#
# Refitting: fertilizer_percent | Random | jitter_aug ...
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   -> Residuals: Mean=-39.7018, Shapiro P=0.2951, Ljung-Box P=0.7273
# Diagnostics saved: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN\RESIDCNN_imports_percent.png
# Saving results for CNN | fertilizer_percent...
# Leaderboard updated: fertilizer_percent | CNN
# Save leaderboard complete.
# DONE
#
# Refitting: fertilizer_percent | TPE | orig ...
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   -> Residuals: Mean=-43.9661, Shapiro P=0.5520, Ljung-Box P=0.4679
# Diagnostics saved: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN\RESIDCNN_imports_percent.png
# Saving results for CNN | fertilizer_percent...
# Leaderboard updated: fertilizer_percent | CNN
# Save leaderboard complete.
# DONE
#
# Refitting: fertilizer_percent | TPE | step_aug ...
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   -> Residuals: Mean=-54.8410, Shapiro P=0.3957, Ljung-Box P=0.8597
# Diagnostics saved: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN\RESIDCNN_imports_percent.png
# Saving results for CNN | fertilizer_percent...
# Leaderboard updated: fertilizer_percent | CNN
# Save leaderboard complete.
# DONE
#
# Refitting: fertilizer_percent | TPE | jitter_aug ...
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   -> Residuals: Mean=-44.7677, Shapiro P=0.4905, Ljung-Box P=0.3661
# Diagnostics saved: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_residCNN\RESIDCNN_imports_percent.png
# Saving results for CNN | fertilizer_percent...
# Leaderboard updated: fertilizer_percent | CNN
# Save leaderboard complete.
# DONE
#
# Completed CNN refitting.

# %%
for indicator in INDICATORS:
    if indicator not in orig_aug_subsets:
        print(f"Skipping {indicator}: missing orig_aug_subsets")
        continue

    try:
        train_orig = orig_aug_subsets[indicator]['orig_train']
        val_orig = orig_aug_subsets[indicator]['orig_val']
        test_orig = orig_aug_subsets[indicator]['orig_test']
    except KeyError:
        print(f"Skipping {indicator}: missing one of orig_train/orig_val/orig_test")
        continue

    if indicator not in predictions_dict:
        print(f"Skipping {indicator}: no predictions available")
        continue

    print(f"\nPlotting predictions for: {indicator}")
    visual.plot_nn_preds(
        indicator,
        predictions_dict,
        train_orig,
        val_orig,
        test_orig,
        model_name="CNN",
        folder_name="09_CNN"
    )

    for sampler, cats in predictions_dict[indicator].items():
        for cat, res in cats.items():
            yrs = res.get("years")
            vals = res.get("y_pred")
            if yrs is None or vals is None:
                print(f"{sampler} | {cat}: missing years or preds")
            else:
                print(f"{sampler} | {cat} -> years: {yrs.tolist()} preds: {np.round(vals,4).tolist()}")
# Out:
# Plotting predictions for: fertilizer_percent
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_CNN\CNN_fertilizer_percent.png
# Random | orig -> years: [2020, 2021, 2022] preds: [169.26449584960938, 153.26300048828125, 136.49090576171875]
# Random | step_aug -> years: [2020, 2021, 2022] preds: [179.65469360351562, 174.79550170898438, 156.2677001953125]
# Random | jitter_aug -> years: [2019, 2020, 2021, 2022] preds: [159.2335968017578, 161.968505859375, 145.69619750976562, 122.36380004882812]
# TPE | orig -> years: [2019, 2020, 2021, 2022] preds: [153.789306640625, 159.00900268554688, 154.14939880371094, 139.37159729003906]
# TPE | step_aug -> years: [2020, 2021, 2022] preds: [184.1136932373047, 156.7646026611328, 135.00259399414062]
# TPE | jitter_aug -> years: [2020, 2021, 2022] preds: [150.64210510253906, 152.5093994140625, 142.5095977783203]

# %% [markdown]
# ## <a id='toc1_8_'></a>[Future preds - REFITTING ON FULL TIME SERIES](#toc0_)

# %% [markdown]
# provo a fare predizioni prendendo come train set tutta la time serie, no validation set.

# %%
forecasts_2030 = {}
TARGET_YEAR = 2030

tf.keras.utils.set_random_seed(RANDOM_SEED)
tf.config.experimental.enable_op_determinism()

print(f"Deployment {TARGET_YEAR} predictions:")

for entry in tuning_results:
    indicator = entry['indicator']
    cat = entry['dataset_type']  # orig, step_aug, jitter_aug
    sampler = entry['sampler']   # Random o TPE
    params = entry['best_params'].copy()
    
    print(f"\nProcessing: {indicator} | {sampler} | {cat}")

    full_df = orig_aug_subsets[indicator]['full_orig'].sort_values('Year')
    
    if full_df.empty:
        print(f"Error: missing data for {indicator}")
        continue

    x_train_vals = full_df['Year']
    y_train_vals = full_df['Value'].values
    
    if cat == 'step_aug':
        step_train_set = pipe.augment_step_function(x_train_vals, y_train_vals, scale_factor=10) 
        final_train_values = step_train_set['Value'].values
    elif cat == 'jitter_aug':
        jitter_train_set = pipe.augment_linear_with_jitter(x_train_vals, y_train_vals, scale_factor=10, noise_level=0.05)
        final_train_values = jitter_train_set['Value'].values
    else: # 'orig'
        final_train_values = full_df['Value'].values

    # Scaling
    scaler_full = MinMaxScaler()
    full_values_reshaped = y_train_vals.reshape(-1, 1)
    scaler_full.fit(full_values_reshaped)
    
    # Transform dei dati che useremo per il training (che possono essere aumentati)
    train_values_scaled = scaler_full.transform(final_train_values.reshape(-1, 1)).flatten()

    # Creazione Sequenze con n_input_steps ottimizzato
    n_steps = params['n_input_steps']
    X_full, y_full = pipe.create_sequences(pd.Series(train_values_scaled), n_steps)

    if len(X_full) == 0:
        print(f"Insufficient data for n_steps={n_steps} -> skip")
        continue

    # Reshape per CNN (Samples, TimeSteps, Features)
    X_full = X_full.reshape((X_full.shape[0], X_full.shape[1], 1))
    
    # Training
    params['input_shape'] = (n_steps, 1)
    model = nn.build_cnn_model(params)
    
    model.fit(
        X_full, y_full,
        batch_size=params['batch_size'],
        epochs=150, 
        verbose=0 
    )
    
    # Recursive Forecasting Loop 
    # Partiamo dagli ultimi dati REALI (non aumentati) per la proiezione
    last_real_data = full_df['Value'].values[-n_steps:]
    last_window_scaled = scaler_full.transform(last_real_data.reshape(-1, 1))
    
    current_batch = last_window_scaled.reshape((1, n_steps, 1))
    future_preds_scaled = []
    
    last_historical_year = full_df['Year'].max()
    years_to_predict = range(last_historical_year + 1, TARGET_YEAR + 1)
    
    for year in years_to_predict:
        pred_single = model.predict(current_batch, verbose=0)[0, 0]
        future_preds_scaled.append(pred_single)
        
        next_input = np.array([[[pred_single]]]) # (1, 1, 1)
        current_batch = np.concatenate([current_batch[:, 1:, :], next_input], axis=1)
    
    future_preds_real = scaler_full.inverse_transform(np.array(future_preds_scaled).reshape(-1, 1)).flatten()

    forecasts_2030.setdefault(indicator, {})
    forecasts_2030[indicator].setdefault(sampler, {})
    
    forecasts_2030[indicator][sampler][cat] = {
        'years': list(years_to_predict),
        'y_pred': future_preds_real,
        'params': params
    }
    print(f"{indicator} | {sampler} | {cat} -> 2030: {future_preds_real[-1]:.2f}")
    tf.keras.backend.clear_session()
    del model
    gc.collect()
print(f"\nCompleted deployment. Processed indicators: {len(forecasts_2030)}")
# Out:
# Deployment 2030 predictions:
#
# Processing: fertilizer_percent | Random | orig
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# fertilizer_percent | Random | orig -> 2030: 168.34
#
# Processing: fertilizer_percent | Random | step_aug
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# fertilizer_percent | Random | step_aug -> 2030: 97.55
#
# Processing: fertilizer_percent | Random | jitter_aug
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# fertilizer_percent | Random | jitter_aug -> 2030: 115.01
#
# Processing: fertilizer_percent | TPE | orig
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# fertilizer_percent | TPE | orig -> 2030: 168.23
#
# Processing: fertilizer_percent | TPE | step_aug
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# fertilizer_percent | TPE | step_aug -> 2030: 94.86
#
# Processing: fertilizer_percent | TPE | jitter_aug
# c:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# fertilizer_percent | TPE | jitter_aug -> 2030: 106.02
#
# Completed deployment. Processed indicators: 1

# %%
for indicator, samplers in forecasts_2030.items():
    try:
        train_orig = orig_aug_subsets[indicator]['orig_train']
        val_orig = orig_aug_subsets[indicator]['orig_val']
        test_orig = orig_aug_subsets[indicator]['orig_test']
    except KeyError:
        print(f"Missing historical subsets for {indicator} -> skip")
        continue
    
    for sampler, datasets in samplers.items():
        for ds_type, res in datasets.items():
            if 'years' in res and isinstance(res['years'], list):
                res['years'] = np.array(res['years'])
            
            if 'y_pred' in res and isinstance(res['y_pred'], list):
                res['y_pred'] = np.array(res['y_pred'])

    visual.plot_nn_preds(
        variable_name=indicator,
        predictions_dict=forecasts_2030,
        train_df=train_orig,
        val_df=val_orig,
        test_df=test_orig,
        model_name="CNN",
        folder_name="09_futureCNN"
    )
# Out:
# DEBUG: Cartella creata: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_futureCNN
# Grafico salvato in: C:\Users\oldan\Desktop\RuralDevelopment\progetto-tirocinio\results\plots\09_futureCNN\CNN_fertilizer_percent.png
